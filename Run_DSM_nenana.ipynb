# %%
import os 
#import wget
import urllib.request
import requests
import tarfile
import fileinput
from pysep import recsec
from pysep.recsec import plotw_rs,RecordSection
from obspy import read, Stream,read_events
from glob import glob
import pandas as pd
from pysep.utils.io import read_sem, read_sem_cartesian
from pysep.utils.io import read_specfem3d_cmtsolution_cartesian,read_stations
from obspy.geodetics import gps2dist_azimuth, kilometer2degrees
import numpy as np

# %%
mpi=1
if mpi==1:

    url_dsm='https://www.eri.u-tokyo.ac.jp/people/takeuchi/software/dsmti-2.2.10.tar'
    dsmti_file = urllib.request.urlretrieve(url_dsm,'dsmti-2.2.10.tar')
else:
    url_dsm ='https://www.eri.u-tokyo.ac.jp/people/takeuchi/software/dsmti-3.1.8.tar'
    dsmti_file = urllib.request.urlretrieve(url_dsm,'dsmti-3.1.8.tar')
#dsmti_file=wget.download(url_dsm)
work_dir='dsm_work'
# open file
file = tarfile.open(dsmti_file[0])
try:
    os.mkdir(work_dir)
except:
    print('skip mkdir')
# extracting file
file.extractall(work_dir)
file.close()
#os.remove(dsmti_file[0])

# %% [markdown]
# Compile

# %%
maxngrid_r=100000
maxlmax=40000
maxn_structure_zone = 12
max_nstation = 100
maxnfreq = 8192
os.chdir(work_dir+'/'+dsmti_file[0][:-4])
#os.chdir('./dsm_work/dsmti-3.1.8')
makefile='Makefile'
dsmtif='dsmti.f'
with fileinput.FileInput(makefile, 
                         inplace = True, backup ='.bak') as f:     
    for line in f:
        if "mpif77" in line and mpi==1:
            print(line.replace("mpif77",
                               "mpif77 -std=legacy"), end ='')
        
        elif "f77" in line and mpi!=1:
            print(line.replace("f77",
                               "gfortran -std=legacy"), end ='')
        else:
            print(line, end ='')
with fileinput.FileInput(dsmtif, 
                         inplace = True, backup ='.bak') as f:
      
    for line in f:
        if "parameter ( maxngrid_r" in line:
            print('	parameter ( maxngrid_r= '+str(maxngrid_r)+' )', end ='\n')
        elif "parameter ( maxlmax" in line:
            print('	parameter ( maxlmax= '+str(maxlmax)+' )', end ='\n')
        elif "parameter ( max_nstation" in line:
            print('	parameter ( max_nstation= '+str(max_nstation)+' )', end ='\n')
        elif "parameter ( maxn_structure_zone" in line:
            print('	parameter ( maxn_structure_zone= '+str(maxn_structure_zone)+' )', end ='\n')
        elif "parameter ( maxnfreq" in line:
            print('	parameter ( maxnfreq= '+str(maxnfreq)+' )', end ='\n')
        else:
            print(line, end ='')
# !make clean
# !make
# Out:
# rm -f param.o matrix.o compwave.o msub.o sacconv.o sacbw.o dsmti.o dsmti *~
# make dsmti
# mpif77 -std=legacy -c -O param.f
# param.f:122:21:
#
#   122 |      &                real(station_lat(i)),real(station_lon(i)),
#       |                      1
# Warning: Rank mismatch in argument 'ths' at (1) (rank-1 and scalar)
# param.f:122:42:
#
#   122 |      &                real(station_lat(i)),real(station_lon(i)),
#       |                                           1
# Warning: Rank mismatch in argument 'phs' at (1) (rank-1 and scalar)
# param.f:123:23:
#
#   123 |      &                1,dist,az,baz,xdeg,nerr)
#       |                        1
# Warning: Rank mismatch in argument 'dist' at (1) (rank-1 and scalar)
# param.f:123:28:
#
#   123 |      &                1,dist,az,baz,xdeg,nerr)
#       |                             1
# Warning: Rank mismatch in argument 'az' at (1) (rank-1 and scalar)
# param.f:123:31:
#
#   123 |      &                1,dist,az,baz,xdeg,nerr)
#       |                                1
# Warning: Rank mismatch in argument 'baz' at (1) (rank-1 and scalar)
# param.f:123:35:
#
#   123 |      &                1,dist,az,baz,xdeg,nerr)
#       |                                    1
# Warning: Rank mismatch in argument 'xdeg' at (1) (rank-1 and scalar)
# mpif77 -std=legacy -c -O matrix.f
# mpif77 -std=legacy -c -O compwave.f
# mpif77 -std=legacy -c -O msub.f
# msub.f:26:23:
#
#    11 |       call mpi_unpack( dbuff,mbfd*8,dpos,dv,ml,mpi_double_precision,
#       |                       2
# ......
#    26 |       call mpi_unpack( ibuff,mbfi*4,ipos,iv,ml,mpi_integer,
#       |                       1
# Warning: Type mismatch between actual argument at (1) and actual argument at (2) (INTEGER(4)/REAL(8)).
# msub.f:26:41:
#
#    11 |       call mpi_unpack( dbuff,mbfd*8,dpos,dv,ml,mpi_double_precision,
#       |                                         2
# ......
#    26 |       call mpi_unpack( ibuff,mbfi*4,ipos,iv,ml,mpi_integer,
#       |                                         1
# Warning: Type mismatch between actual argument at (1) and actual argument at (2) (INTEGER(4)/REAL(8)).
# msub.f:80:21:
#
#    65 |       call mpi_pack( dv,ml,mpi_double_precision,dbuff,mbfd*8,dpos,
#       |                     2
# ......
#    80 |       call mpi_pack( iv,ml,mpi_integer,ibuff,mbfi*4,ipos,
#       |                     1
# Warning: Type mismatch between actual argument at (1) and actual argument at (2) (INTEGER(4)/REAL(8)).
# msub.f:80:39:
#
#    65 |       call mpi_pack( dv,ml,mpi_double_precision,dbuff,mbfd*8,dpos,
#       |                                                2
# ......
#    80 |       call mpi_pack( iv,ml,mpi_integer,ibuff,mbfi*4,ipos,
#       |                                       1
# Warning: Type mismatch between actual argument at (1) and actual argument at (2) (INTEGER(4)/REAL(8)).
# msub.f:112:25:
#
#   101 |         call mpi_recv( param,4,mpi_integer,np,mt+100000,
#       |                       2
# ......
#   112 |           call mpi_recv( dbuff,numd,mpi_double_precision,np,mt+120000,
#       |                         1
# Warning: Type mismatch between actual argument at (1) and actual argument at (2) (REAL(8)/INTEGER(4)).
# msub.f:146:27:
#
#   139 |           call mpi_send( param,4,mpi_integer,np,mt+100000,
#       |                         2
# ......
#   146 |             call mpi_send( dbuff,dpos/8,mpi_double_precision,np,
#       |                           1
# Warning: Type mismatch between actual argument at (1) and actual argument at (2) (REAL(8)/INTEGER(4)).
# mpif77 -std=legacy -c -O sacconv.f
# sacconv.f:192:30:
#
#   192 |         call distaz1( evla,evlo,stla,stlo,1,dist,az,baz,gcarc,ier )
#       |                                     1
# Warning: Rank mismatch in argument 'ths' at (1) (rank-1 and scalar)
# sacconv.f:192:35:
#
#   192 |         call distaz1( evla,evlo,stla,stlo,1,dist,az,baz,gcarc,ier )
#       |                                          1
# Warning: Rank mismatch in argument 'phs' at (1) (rank-1 and scalar)
# sacconv.f:192:42:
#
#   192 |         call distaz1( evla,evlo,stla,stlo,1,dist,az,baz,gcarc,ier )
#       |                                                 1
# Warning: Rank mismatch in argument 'dist' at (1) (rank-1 and scalar)
# sacconv.f:192:47:
#
#   192 |         call distaz1( evla,evlo,stla,stlo,1,dist,az,baz,gcarc,ier )
#       |                                                      1
# Warning: Rank mismatch in argument 'az' at (1) (rank-1 and scalar)
# sacconv.f:192:50:
#
#   192 |         call distaz1( evla,evlo,stla,stlo,1,dist,az,baz,gcarc,ier )
#       |                                                         1
# Warning: Rank mismatch in argument 'baz' at (1) (rank-1 and scalar)
# sacconv.f:192:54:
#
#   192 |         call distaz1( evla,evlo,stla,stlo,1,dist,az,baz,gcarc,ier )
#       |                                                             1
# Warning: Rank mismatch in argument 'xdeg' at (1) (rank-1 and scalar)
# sacconv.f:45:72:
#
#    45 |             call four1( work_spc,nn,isign )
#       |                                                                               1
# Warning: Type mismatch in argument 'data' at (1); passed COMPLEX(8) to REAL(8)
# mpicc -c -O sacbw.c
# mpif77 -std=legacy -c -O dsmti.f
# dsmti.f:177:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
#   176 |           call mputd( omega_imag,1,info )
#   177 |           call mputd( rmin_structure_zone,maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:178:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   178 |           call mputd( rmax_structure_zone,maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:179:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   179 |           call mputd( rho_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:180:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   180 |           call mputd( vpv_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:181:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   181 |           call mputd( vph_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:182:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   182 |           call mputd( vsv_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:183:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   183 |           call mputd( vsh_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:184:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   184 |           call mputd( eta_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:185:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   185 |           call mputd( qkappa_structure_zone,maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:186:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   186 |           call mputd( qmu_structure_zone,maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:188:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   188 |           call mputd( source_mt,9,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:189:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   189 |           call mputd( station_theta,max_nstation,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:190:20:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   190 |           call mputd( station_phi,max_nstation,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:202:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
#   201 |           call mgetd( omega_imag,1,info )
#   202 |           call mgetd( rmin_structure_zone,maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:203:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   203 |           call mgetd( rmax_structure_zone,maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:204:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   204 |           call mgetd( rho_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:205:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   205 |           call mgetd( vpv_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:206:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   206 |           call mgetd( vph_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:207:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   207 |           call mgetd( vsv_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:208:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   208 |           call mgetd( vsh_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:209:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   209 |           call mgetd( eta_structure_zone,4*maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:210:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   210 |           call mgetd( qkappa_structure_zone,maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:211:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   211 |           call mgetd( qmu_structure_zone,maxn_structure_zone,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:213:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   213 |           call mgetd( source_mt,9,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-2)
# dsmti.f:214:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   214 |           call mgetd( station_theta,max_nstation,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:215:20:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   215 |           call mgetd( station_phi,max_nstation,info )
#       |                           1
# Warning: Rank mismatch between actual argument at (1) and actual argument at (2) (scalar and rank-1)
# dsmti.f:414:24:
#
#   175 |           call mputd( time_series_length,1,info )
#       |                           2
# ......
#   414 |               call mputd( station_displacement(1,1,i_frequency),
#       |                               1
# Warning: Type mismatch between actual argument at (1) and actual argument at (2) (COMPLEX(8)/REAL(8)).
# dsmti.f:431:26:
#
#   200 |           call mgetd( time_series_length,1,info )
#       |                           2
# ......
#   431 |                 call mgetd( station_displacement(1,1,i_frequency),
#       |                                 1
# Warning: Type mismatch between actual argument at (1) and actual argument at (2) (COMPLEX(8)/REAL(8)).
# mpif77 -std=legacy -O param.o matrix.o compwave.o msub.o sacconv.o sacbw.o dsmti.o -o dsmti

# %% [markdown]
# Config input files

# %%
stations_path='../../STATIONS_FILTERED'
cmt_path='../../CMTSOLUTION_20160124103029557'
stas =pd.read_fwf(stations_path,header=None,index=None)
#source=read_specfem3d_cmtsolution_cartesian(cmt_path)
stations=read_stations(stations_path)
source=read_events(cmt_path, format="CMTSOLUTION")[0]
src_moment=source.focal_mechanisms[0].moment_tensor
sorce_origin=source.preferred_origin()
nexp0=np.round(np.log10(src_moment.scalar_moment))

# %%
in_para_file='./data/010109.inf'
out_dir_dsm='data/'
time_series_length, n_freqnency=256,512
ngrid_r,lmin,lmax=9000,0,9000
with open(in_para_file, "r") as fl:
        lines = fl.readlines() 
for i,line in enumerate(lines):
        if i==4:
                lines[i]=f'  {time_series_length:5.1f}{n_freqnency:5}  time_series_length, n_freqnency \n'
        if 'ngrid_r  lmin   lmax' in line:
                lines[i+2]=f'   {ngrid_r:5} {lmin:5}  {lmax:5} \n'
        if 'nexp,source_mt' in line:
                source_para=f'{int(nexp0+7):5}  {src_moment.tensor.m_rr/10**nexp0:2.4f} {src_moment.tensor.m_tt/10**nexp0:2.4f} \
{src_moment.tensor.m_pp/10**nexp0:2.4f} {src_moment.tensor.m_rt/10**nexp0:2.4f} \
{src_moment.tensor.m_rp/10**nexp0:2.4f} {src_moment.tensor.m_tp/10**nexp0:2.4f}'+'    nexp,source_mt \n'
                lines[i]=source_para
        if 'source_depth,source_lat,sourth_lon' in line:
                origin=f'{sorce_origin.depth/1000} {sorce_origin.latitude:.2f} {sorce_origin.longitude:.2f}'+'  source_depth,source_lat,sourth_lon \n'
                lines[i]=origin
        if 'number of stations' in line:
                i_sta=i
                lines[i+1]=f'{len(stas):d} n_station \n'

del lines[i_sta+3:]

for i in range(len(stas)):
        lines.append(f'{stas.loc[i,2]:f} {stas.loc[i,3]:f} {stas.loc[i,0]} \n')
lines.append('c --- output files \n')
for i in range(len(stas)):
        lines.append(out_dir_dsm+'010109.'+stas.loc[i,0]+'\n')
lines.append('c\n')
lines.append('end\n')

os.rename(in_para_file,in_para_file+'.bak')
with open(in_para_file, 'w') as f:
    for line in lines:
        f.write(f"{line}")

# %% [markdown]
# Run the simulation

# %%
chinook=0
num_cores=8
if mpi==1:
    if chinook==1:
        run_chi_file='submit_chinook.bash'
#num_cores=8
        os.system('cp ../../'+run_chi_file+' '+'./')
        with fileinput.FileInput(run_chi_file,
                         inplace = True, backup ='.bak') as f:
            for line in f:
                if 'NPROC=' in line:
                    print(f'NPROC={num_cores:d}', end ='\n')
                elif 'ntasks' in line:
                    print(f'#SBATCH --ntasks={num_cores:d}')
                else:
                    print(line, end ='')
        os.system('sbatch submit_chinook.bash')
    else:
        os.system(f'mpirun -np {num_cores} dsmti  <data/010109.inf')
else:
    os.system('./dsmti  <data/010109.inf')

# %% [markdown]
# Plot the record section (PySep)

# %%
# !pwd
# Out:
# /Users/yuantian/software/SCOPED_yuan/dsm_work/dsmti-2.2.10

# %%
data_path='./data'
cpnt='bhz'
def get_obspy_st(data_path,cpnt):
    fids=glob(os.path.join(data_path, "*."+cpnt))
    st = Stream()
    for fid in fids:
        st += read(fid)
    for i,tr in enumerate(st):
        otime=tr.stats.starttime
        dist_deg = kilometer2degrees(tr.stats.sac.dist) 
        tr.stats.network='XX'
        tr.stats.station=fids[i].split(sep='.')[-2]
        tr.stats.channel=cpnt.upper()
        tr.stats.sac = {
                "iztype": 9,  # Ref time equivalence, IB (9): Begin time
                "b": tr.stats.sac.b,  # begin time
                "e": tr.stats.npts * tr.stats.delta,  # end time
                "evla": tr.stats.sac.evla,
                "evlo": tr.stats.sac.evlo,
                "stla": tr.stats.sac.stla,
                "stlo": tr.stats.sac.stlo,
                "stel": 0,  # elevation in km
                "kevnm": str(tr.stats.starttime),  # only take date code
                "nzyear": otime.year,
                "nzjday": otime.julday,
                "nzhour": otime.hour,
                "nzmin": otime.minute,
                "nzsec": otime.second,
                "nzmsec": otime.microsecond,
                "dist": tr.stats.sac.dist,
                "az": tr.stats.sac.az,  # degrees
                "baz": tr.stats.sac.baz,  # degrees
                "gcarc": dist_deg,  # degrees
                "lpspol": 0,  # 1 if left-hand polarity (usually no in passive seis)
                "lcalda": 1,  # 1 if DIST, AZ, BAZ, GCARC to be calc'd from metadata
            }
    return st
st=get_obspy_st(data_path,cpnt)

# %%
plotw_rs(st=st,overwrite=True,scale_by='global_norm',
            sort_by='distance',preprocess='st',xlim_s=[0,time_series_length])
# Out:
# [2023-03-06 13:45:34] - pysep - INFO: starting record section plotter
# [2023-03-06 13:45:34] - pysep - INFO: checking parameter acceptability
# [2023-03-06 13:45:34] - pysep - INFO: getting source-receiver stats
# [2023-03-06 13:45:34] - pysep - INFO: calculating source-receiver distance and (back)azimuths
# [2023-03-06 13:45:34] - pysep - INFO: preprocessing 24 `st` waveforms
# [2023-03-06 13:45:34] - pysep - INFO: no filtering applied
# [2023-03-06 13:45:34] - pysep - INFO: calculating starttime offsets from event origin time 1969-12-31T23:55:44.000000Z
# [2023-03-06 13:45:34] - pysep - INFO: determining sort order with parameter: distance
# [2023-03-06 13:45:34] - pysep - INFO: determining if any stations/channels should be skipped
# [2023-03-06 13:45:34] - pysep - INFO: criteria check will remove 0/24 traces
# [2023-03-06 13:45:34] - pysep - INFO: determining y-axis positioning for sort: distance
# [2023-03-06 13:45:34] - pysep - INFO: determining amplitude scaling with: 'global_norm'
# [2023-03-06 13:45:34] - pysep - INFO: plotting record section for 24 waveforms
# [2023-03-06 13:45:34] - pysep - DEBUG: plotting line check starting from bottom (y=0)
# [2023-03-06 13:45:34] - pysep - DEBUG:
# IDX	Y		ID	DIST	AZ	BAZ	TSHIFT	TOFFSET	YABSMAX
# [2023-03-06 13:45:34] - pysep - DEBUG:
# 4	0	XX.POKR..BHZ	684.04	 23.93	209.17	0.00	0.00	2.52E-02
# 23	1	XX.MDM..BHZ	651.05	 21.77	206.29	0.00	0.00	2.80E-02
# 14	2	XX.TCOL..BHZ	650.51	 23.53	208.38	0.00	0.00	2.70E-02
# 20	3	XX.I23K..BHZ	649.28	 16.73	200.26	0.00	0.00	3.05E-02
# 15	4	XX.CCB..BHZ	629.57	 24.85	209.75	0.00	0.00	2.84E-02
# 11	5	XX.F5MN..BHZ	625.06	 18.39	202.07	0.00	0.00	3.17E-02
# 21	6	XX.F4TN..BHZ	620.23	 18.71	202.41	0.00	0.00	3.21E-02
# 6	7	XX.MLY..BHZ	617.69	 11.44	193.74	0.00	0.00	3.44E-02
# 2	8	XX.F6TP..BHZ	616.95	 16.90	200.25	0.00	0.00	3.26E-02
# 19	9	XX.F3TN..BHZ	613.93	 18.98	202.69	0.00	0.00	3.17E-02
# 12	10	XX.FTGH..BHZ	611.86	 20.62	204.61	0.00	0.00	3.11E-02
# 5	11	XX.F7TV..BHZ	611.01	 15.85	198.96	0.00	0.00	3.39E-02
# 22	12	XX.F2TN..BHZ	607.76	 19.29	203.01	0.00	0.00	3.21E-02
# 7	13	XX.WRH..BHZ	605.95	 24.63	209.26	0.00	0.00	2.94E-02
# 18	14	XX.F1TN..BHZ	601.65	 19.41	203.10	0.00	0.00	3.29E-02
# 10	15	XX.F8KN..BHZ	600.07	 15.70	198.72	0.00	0.00	3.46E-02
# 0	16	XX.FPAP..BHZ	598.55	 19.83	203.58	0.00	0.00	3.29E-02
# 16	17	XX.NEA2..BHZ	597.06	 20.05	203.82	0.00	0.00	3.30E-02
# 8	18	XX.NEA..BHZ	596.98	 20.04	203.82	0.00	0.00	3.31E-02
# 9	19	XX.FAPT..BHZ	592.41	 20.18	203.94	0.00	0.00	3.28E-02
# 13	20	XX.FNN1..BHZ	592.06	 19.51	203.15	0.00	0.00	3.36E-02
# 17	21	XX.FNN2..BHZ	588.29	 18.51	201.95	0.00	0.00	3.39E-02
# 1	22	XX.BWN..BHZ	549.85	 20.95	204.51	0.00	0.00	3.67E-02
# 3	23	XX.BPAW..BHZ	514.28	 12.90	194.97	0.00	0.00	4.54E-02
#
# [2023-03-06 13:45:34] - pysep - INFO: placing station labels on y-axis at: y_axis
# [2023-03-06 13:45:34] - pysep - INFO: saving figure to ./record_section.png
# [2023-03-06 13:45:35] - pysep - INFO: finished record section in t=0:00:00.591689s
